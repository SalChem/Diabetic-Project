# %% [markdown]
# # Glucose Levels at meal time for all patients

# %% [markdown]
# ## Patient 1

# %% [markdown]
# There are 75 valid meals based on the assumptions.

# %% [markdown]
# **The glucose mean at the time of the recorded meals is: 99.84 mg/dL with a std of: 17.5408399647**

# %%
from IPython.display import Image
#If the image is not on the same path, use next line
#fig_path = os.path.join(_FIG_DIR, 'Assumption 1.png')
Image(filename= 'Figures\Patient 1 Meal times.png')

# %% [markdown]
# The meal Carbs mean is: 48.9274533333 grams with a std of: 26.6488760625 grams.
#
# The meal Fat mean is: 2.58132 grams with a std of: 4.21724775388 grams.
#
# The meal Protein mean is: 4.99675 grams with a std of: 3.41922256588 grams.

# %%
Image(filename= 'Figures\Patient 1 Meals.png')

# %% [markdown]
# ## Patient 2

# %% [markdown]
# There are 31 valid meals based on the assumptions.

# %% [markdown]
# **The glucose mean at the time of the recorded meals is: 103.677419355 mg/dL with a std of: 12.2088997068**

# %%
Image(filename= 'Figures\Patient 2 Meal times.png')

# %% [markdown]
# The meal Carbs mean is: 52.1151612903 grams with a std of: 26.6958674138 grams.
#
# The meal Fat mean is: 6.13767822581 grams with a std of: 6.08641387351 grams.
#
# The meal Protein mean is: 6.81977177419 grams with a std of: 4.08101565921 grams.

# %%
Image(filename= 'Figures\Patient 2 Meals.png')

# %% [markdown]
# ## Patient 3

# %% [markdown]
# There are 7 valid meals based on the assumptions.

# %% [markdown]
# **The glucose mean at the time of recorded meals is: 108.714285714 mg/dL with a std of: 11.1446884942**

# %%
Image(filename= 'Figures\Patient 3 Meal times.png')

# %% [markdown]
# The meal Carbs mean is: 69.6728571429 grams with a std of: 51.4376789952 grams.
#
# The meal Fat mean is: 6.11585714286 grams with a std of: 4.90163906052 grams.
#
# The meal Protein mean is: 6.39428571429 grams with a std of: 2.55361323642 grams.

# %%
Image(filename= 'Figures\Patient 3 Meals.png')

# %% [markdown]
# ## Patient 4

# %% [markdown]
# There are 47 valid meals based on the assumptions.

# %% [markdown]
# **The glucose mean at the time of recorded meals is: 108.404255319 mg/dL with a std of: 12.2988661897**

# %%
Image(filename= 'Figures\Patient 4 Meal times.png')

# %% [markdown]
# The meal Carbs mean is: 57.3168404262 grams with a std of: 31.7441253331 grams.
#
# The meal Fat mean is: 4.8391968086 grams with a std of: 4.53575091844 grams.
#
# The meal Protein mean is: 7.16548642355 grams with a std of: 4.35408756051 grams.

# %%
Image(filename= 'Figures\Patient 4 Meals.png')

# %% [markdown]
# ## Patient 5

# %% [markdown]
# There are 90 valid meals based on the assumptions.

# %% [markdown]
# **The glucose mean at the time of recorded meals is: 119.777777778 mg/dL with a std of: 19.8184974079**

# %%
Image(filename= 'Figures\Patient 5 Meal times.png')

# %% [markdown]
# The meal Carbs mean is: 83.7254587308 grams with a std of: 73.0863027929 grams.
#
# The meal Fat mean is: 4.86182047621 grams with a std of: 5.04545076416 grams.
#
# The meal Protein mean is: 8.45816724861 grams with a std of: 10.7027983432 grams.

# %%
Image(filename= 'Figures\Patient 5 Meals.png')
