# %% [markdown]
# # Patient 1 Stats

# %% [markdown]
# This patient has a total of 91 meals of the following sizes:
#
# There are 5 meals with CHO less than 5.0 grams.
#
# There are 14 meals with CHO between 5.0 and 10.0 grams.
#
# There are 17 meals with CHO between 10.0 and 15.0 grams.
#
# There are 12 meals with CHO between 15.0 and 20.0 grams.
#
# There are 11 meals with CHO between 20.0 and 25.0 grams.
#
# There are 23 meals with CHO between 25.0 and 30.0 grams.
#
# There are 2 meals with CHO between 30.0 and 35.0 grams.
#
# There are 3 meals with CHO between 35.0 and 40.0 grams.
#
# There are 1 meals with CHO between 40.0 and 45.0 grams.
#
# There are 1 meals with CHO between 45.0 and 50.0 grams.
#
# There are 1 meals with CHO between 50.0 and 55.0 grams.
#
# There are 1 meals with CHO between 55.0 and 60.0 grams.
#
#
# The are 2 occurrences of meals of size less than 1gram of CHO
#
# The mean of the total # of meals is: 19.7991758242
#
# The std of the total # of meals is: 10.8535967352
#
# The min meal size is: 0.5 while the max meal size is: 56.0

# %% [markdown]
# # Patient 2 Stats

# %% [markdown]
# This patient has a total of 89 meals of the following sizes:
#
# There are 26 meals with CHO less than 5.0 grams.
#
# There are 13 meals with CHO between 5.0 and 10.0 grams.
#
# There are 20 meals with CHO between 10.0 and 15.0 grams.
#
# There are 15 meals with CHO between 15.0 and 20.0 grams.
#
# There are 7 meals with CHO between 20.0 and 25.0 grams.
#
# There are 2 meals with CHO between 25.0 and 30.0 grams.
#
# There are 3 meals with CHO between 30.0 and 35.0 grams.
#
# There are 0 meals with CHO between 35.0 and 40.0 grams.
#
# There are 0 meals with CHO between 40.0 and 45.0 grams.
#
# There are 0 meals with CHO between 45.0 and 50.0 grams.
#
# There are 0 meals with CHO between 50.0 and 55.0 grams.
#
# There are 0 meals with CHO between 55.0 and 60.0 grams.
#
# There are 0 meals with CHO between 60.0 and 65.0 grams.
#
# There are 1 meals with CHO between 65.0 and 70.0 grams.
#
# There are 0 meals with CHO between 70.0 and 75.0 grams.
#
# There are 0 meals with CHO between 75.0 and 80.0 grams.
#
# There are 0 meals with CHO between 80.0 and 85.0 grams.
#
# There are 0 meals with CHO between 85.0 and 90.0 grams.
#
# There are 2 meals with CHO between 90.0 and 95.0 grams.
#
# The are 7 occurrences of meals of size less than 1gram of CHO
#
# The mean of the total # of meals is: 13.6007458801
#
# The std of the total # of meals is: 15.8886105736
#
# The min meal size is: 0.0 while the max meal size is: 92.9

# %% [markdown]
# # Patient 3 Stats

# %% [markdown]
# This patient has a total of 25 meals of the following sizes:
#
# There are 12 meals with CHO less than 5.0 grams.
#
# There are 3 meals with CHO between 5.0 and 10.0 grams.
#
# There are 0 meals with CHO between 10.0 and 15.0 grams.
#
# There are 0 meals with CHO between 15.0 and 20.0 grams.
#
# There are 4 meals with CHO between 20.0 and 25.0 grams.
#
# There are 0 meals with CHO between 25.0 and 30.0 grams.
#
# There are 0 meals with CHO between 30.0 and 35.0 grams.
#
# There are 1 meals with CHO between 35.0 and 40.0 grams.
#
# There are 0 meals with CHO between 40.0 and 45.0 grams.
#
# There are 1 meals with CHO between 45.0 and 50.0 grams.
#
# There are 1 meals with CHO between 50.0 and 55.0 grams.
#
# There are 1 meals with CHO between 55.0 and 60.0 grams.
#
# There are 0 meals with CHO between 60.0 and 65.0 grams.
#
# There are 0 meals with CHO between 65.0 and 70.0 grams.
#
# There are 0 meals with CHO between 70.0 and 75.0 grams.
#
# There are 1 meals with CHO between 75.0 and 80.0 grams.
#
# There are 0 meals with CHO between 80.0 and 85.0 grams.
#
# There are 0 meals with CHO between 85.0 and 90.0 grams.
#
# There are 0 meals with CHO between 90.0 and 95.0 grams.
#
# There are 0 meals with CHO between 95.0 and 100.0 grams.
#
# There are 0 meals with CHO between 100.0 and 105.0 grams.
#
# There are 0 meals with CHO between 105.0 and 110.0 grams.
#
# There are 0 meals with CHO between 110.0 and 115.0 grams.
#
# There are 0 meals with CHO between 115.0 and 120.0 grams.
#
# There are 0 meals with CHO between 120.0 and 125.0 grams.
#
# There are 0 meals with CHO between 125.0 and 130.0 grams.
#
# There are 0 meals with CHO between 130.0 and 135.0 grams.
#
# There are 0 meals with CHO between 135.0 and 140.0 grams.
#
# There are 0 meals with CHO between 140.0 and 145.0 grams.
#
# There are 1 meals with CHO between 145.0 and 150.0 grams.
#
# The are 5 occurrences of meals of size less than 1gram of CHO
#
# The mean of the total # of meals is: 21.78324
#
# The std of the total # of meals is: 34.0964518502
#
# The min meal size is: 0.0 while the max meal size is: 149.21

# %% [markdown]
# # Patient 4 Stats

# %% [markdown]
# This patient has a total of 111 meals of the following sizes:
#
# There are 6 meals with CHO less than 5.0 grams.
#
# There are 9 meals with CHO between 5.0 and 10.0 grams.
#
# There are 24 meals with CHO between 10.0 and 15.0 grams.
#
# There are 48 meals with CHO between 15.0 and 20.0 grams.
#
# There are 6 meals with CHO between 20.0 and 25.0 grams.
#
# There are 6 meals with CHO between 25.0 and 30.0 grams.
#
# There are 4 meals with CHO between 30.0 and 35.0 grams.
#
# There are 2 meals with CHO between 35.0 and 40.0 grams.
#
# There are 2 meals with CHO between 40.0 and 45.0 grams.
#
# There are 0 meals with CHO between 45.0 and 50.0 grams.
#
# There are 1 meals with CHO between 50.0 and 55.0 grams.
#
# There are 0 meals with CHO between 55.0 and 60.0 grams.
#
# There are 0 meals with CHO between 60.0 and 65.0 grams.
#
# There are 1 meals with CHO between 65.0 and 70.0 grams.
#
# There are 0 meals with CHO between 70.0 and 75.0 grams.
#
# There are 1 meals with CHO between 75.0 and 80.0 grams.
#
# There are 0 meals with CHO between 80.0 and 85.0 grams.
#
# There are 0 meals with CHO between 85.0 and 90.0 grams.
#
# There are 1 meals with CHO between 90.0 and 95.0 grams.
#
# The are 0 occurrences of meals of size less than 1gram of CHO
#
# The mean of the total # of meals is: 18.5165228228
#
# The std of the total # of meals is: 13.1666783989
#
# The min meal size is: 1.14 while the max meal size is: 93.64

# %% [markdown]
# # Patient 5 Stats

# %% [markdown]
# This patient has a total of 201 meals of the following sizes:
#
# There are 31 meals with CHO less than 5.0 grams.
#
# There are 26 meals with CHO between 5.0 and 10.0 grams.
#
# There are 13 meals with CHO between 10.0 and 15.0 grams.
#
# There are 21 meals with CHO between 15.0 and 20.0 grams.
#
# There are 12 meals with CHO between 20.0 and 25.0 grams.
#
# There are 41 meals with CHO between 25.0 and 30.0 grams.
#
# There are 17 meals with CHO between 30.0 and 35.0 grams.
#
# There are 1 meals with CHO between 35.0 and 40.0 grams.
#
# There are 10 meals with CHO between 40.0 and 45.0 grams.
#
# There are 4 meals with CHO between 45.0 and 50.0 grams.
#
# There are 5 meals with CHO between 50.0 and 55.0 grams.
#
# There are 2 meals with CHO between 55.0 and 60.0 grams.
#
# There are 6 meals with CHO between 60.0 and 65.0 grams.
#
# There are 0 meals with CHO between 65.0 and 70.0 grams.
#
# There are 0 meals with CHO between 70.0 and 75.0 grams.
#
# There are 0 meals with CHO between 75.0 and 80.0 grams.
#
# There are 0 meals with CHO between 80.0 and 85.0 grams.
#
# There are 2 meals with CHO between 85.0 and 90.0 grams.
#
# There are 0 meals with CHO between 90.0 and 95.0 grams.
#
# There are 8 meals with CHO between 95.0 and 100.0 grams.
#
# There are 2 meals with CHO between 100.0 and 105.0 grams.
#
# The are 14 occurrences of meals of size less than 1gram of CHO
#
# The mean of the total # of meals is: 26.382094409
#
# The std of the total # of meals is: 23.5949767726
#
# The min meal size is: 0.0 while the max meal size is: 103.345
